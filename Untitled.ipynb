# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
#Filter the unwanted warning
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_excel("data.xlsx")
df.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
df['existence'].value_counts()
# Out:
# Y      2554
# N      1053
# Yes     557
# No       61
# Name: existence, dtype: int64

# %%
df[df['existence']=='Yes'].head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
df[df['existence']=='Y'].head()
# Out:
#                                                   tweet existence  \
# 1090  Are you ready for the climate change? PLI is w...         Y
# 1091  LIVE TONIGHT: Fellow Heather Rogers joins Clim...         Y
# 1092  Plan B: California Braces for Climate Change. ...         Y
# 1093  Plants effective way of tackling global warmin...         Y
# 1094  @angiemartinez & it's about 2 be 86 degrees ou...         Y
#
#       existence.confidence
# 1090                0.6671
# 1091                1.0000
# 1092                0.6809
# 1093                1.0000
# 1094                0.6760

# %%
df["existence"].value_counts()
# Out:
# Y      2554
# N      1053
# Yes     557
# No       61
# Name: existence, dtype: int64

# %%
#Plotting histogram to see count of each category
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y="existence", data=df, color="c");

# %%
# Seperating independent and dependet variables
X = df['tweet']

Y = []
for x in df['existence']:
    if x=="Y" or x == "Yes":
        Y.append(1)
    else:
        Y.append(0)

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
